# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv('Social_Network_Ads.csv')
data.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
data['Gender'].replace({'Male':0,'Female':1},inplace=True)

# %%
X=data.iloc[:, 1:4].values
y=data.iloc[:,-1].values

# %%
X.shape
# Out:
# (400, 3)

# %%
y.shape
# Out:
# (400,)

# %%
from sklearn.tree import DecisionTreeClassifier
clf1=DecisionTreeClassifier()

# %%
clf1.fit(X,y)
# Out:
# DecisionTreeClassifier()

# %%
#plot trees

# %%
from sklearn.tree import plot_tree
from matplotlib.pylab import rcParams

# %%
rcParams['figure.figsize'] = 50,30

plot_tree(clf1)
plt.savefig("tree_classifier.png")

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree
import matplotlib.pyplot as plt

X=data.iloc[:, 2:4].values
y=data.iloc[:,-1].values
model = DecisionTreeClassifier(criterion='gini', max_depth=2, random_state=42)
model.fit(X, y)

plt.figure(figsize=(10,6))
plot_tree(model, feature_names=['Age', 'EstimatedSalary'], class_names=['No', 'Yes'], filled=True)
plt.show()
plt.savefig("tree_classifier1.png")
